# %% [markdown]
# # COVID Cases Data for various Countries through Supervised Learning
#
# Project Objectives | Problem Statements
#
# 1.1. PO1 | PS1: Segmentation of COVID Cases Data using Supervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Determination of an Appropriate Classification Model
#
# 1.3. PO3 | PS3: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification.
#
# **2. Description of Data**
#
# 2.1. Data Source, Size, Shape
#
# 	2.1.1. Data Source (Original dataset - https://www.kaggle.com/datasets/hosammhmdali/covid-19-dataset; Proj_2 is the dataset used for supervised learning))
#
# 	2.1.2. Data Size (9.78 MB)
#
# 	2.1.3. Data Shape (Dimension: Number of Variables-16 | Number of Records-999990 rows × 18 columns)
#
#   **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s):**
#
# The dataset does not explicitly specify index variables. The index is automatically generated by pandas when reading the dataset.
#
#
# **2.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# 1. iso_code: Country ISO code
# 2. continent: Continent name
# 3. location: Country name
# 4. date: Date of observation
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type**
#
# 1. iso_code (CNV1)
# 2. continent (CNV2)
# 3. location (CNV3)
# 4. Clusters
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# None in the dataset
#
# **2.2.3. Non-Categorical Variables or Features**
#
# 1. total_cases: Total reported COVID-19 cases
# 2. new_cases: New reported COVID-19 cases
# 3. new_cases_smoothed: Smoothed new reported COVID-19 cases
# 4. total_deaths: Total reported COVID-19 deaths
# 5. new_deaths: New reported COVID-19 deaths
# 6. new_deaths_smoothed: Smoothed new reported COVID-19 deaths
# 7. total_cases_per_million: Total reported COVID-19 cases per million people
# 8. new_cases_per_million: New reported COVID-19 cases per million people
# 9. new_cases_smoothed_per_million: Smoothed new reported COVID-19 cases per million people
# 10. total_deaths_per_million: Total reported COVID-19 deaths per million people
# 11. new_deaths_per_million: New reported COVID-19 deaths per million people
# 12. new_deaths_smoothed_per_million: Smoothed new reported COVID-19 deaths per million people
#
# ### **2.3. Descriptive Statistics**
#
# #### 2.3.1. Descriptive Statistics: Categorical Variables or Features
# ##### 2.3.1.1. Count | Frequency Statistics
# **Count of Unique Values in Categorical Features:**
#
# - iso_code Count: 74
# - continent Count: 6
# - location Count: 74
# - date Count: 1367
#
# ##### 2.3.1.2. Proportion (Relative Frequency) Statistics
# - **Proportion of Unique Values in Categorical Features:**
#
# - For iso_code:
#   - ARG: 1.37%
#   - CZE: 1.37%
#   - OWID_EUN: 1.37%
#   - OWID_EUR: 1.37%
#   - BGR: 1.37%
# ... (74 unique ISO codes)
#
# - For continent:
#   - Africa: 28.86%
#   - North America: 24.53%
#   - Europe: 20.11%
#   - Asia: 12.99%
#   - South America: 9.19%
#   - Oceania: 4.33%
#
# - For location:
#   - Argentina: 1.37%
#   - Czechia: 1.37%
#   - European Union: 1.37%
#   - Europe: 1.37%
#   - Bulgaria: 1.37%
# ... (74 unique locations)
#
# - For date:
#   - 24-03-2021: 0.07%
#   - 29-11-2020: 0.07%
#   - 12-12-2020: 0.07%
#   - 11-12-2020: 0.07%
#   - 10-12-2020: 0.07%
# ... (1367 unique dates)
#
# #### **2.3.2. Descriptive Statistics: Non-Categorical Variables or Features**
# ##### **2.3.2.1. Measures of Central Tendency**
#  - Total Cases:
#   - Mean: 5.93 million
#   - Median: 66,218
#
# - New Cases:
#   - Mean: 9.726
#   - Median: 5
#
# - New Cases Smoothed:
#   - Mean: 9.762
#   - Median: 29.43
#
# - Total Deaths:
#   - Mean: 6.36
#   - Median: 1,168
#
# - New Deaths:
#   - Mean: 69.45
#   - Median: 0
#
# - New Deaths Smoothed:
#   - Mean: 69.70
#   - Median: 0.14
#
# - Total Cases Per Million:
#   - Mean: 96,903
#   - Median: 19,343
#
# - New Cases Per Million:
#   - Mean: 142.45
#   - Median: 0.50
#
# - New Cases Smoothed Per Million:
#   - Mean: 142.99
#   - Median: 6.86
#
# - Total Deaths Per Million:
#   - Mean: 852.31
#   - Median: 324.96
#
# - New Deaths Per Million:
#   - Mean: 0.95
#   - Median: 0
#
# - New Deaths Smoothed Per Million:
#   - Mean: 0.96
#   - Median: 0.02
#
# ##### **2.3.2.2. Measures of Dispersion**
# - **Standard Deviation:**
#   - Total Cases: 30,148,910
#   - New Cases: 122,643
#   - New Cases Smoothed: 101,261
#   - Total Deaths: 256,746
#   - New Deaths: 485.51
#   - New Deaths Smoothed: 379.70
#   - Total Cases Per Million: 151,270.3
#   - New Cases Per Million: 800.10
#   - New Cases Smoothed Per Million: 514.07
#   - Total Deaths Per Million: 1,102.21
#   - New Deaths Per Million: 5.24
#   - New Deaths Smoothed Per Million: 2.76
#
# ##### **2.3.2.3. Correlation Statistics (with Test of Correlation)**
# - **Correlation Matrix:**
# 1. total_cases vs. new_cases: 0.266262
# 2. total_cases vs. total_deaths: 0.921228
# 3. new_cases vs. new_deaths: 0.430335
#
# ###**ANALYSIS OF DATA**###
# ### **3.1. Data Pre-Processing**
#
# #### **3.1.1. Missing Data Statistics and Treatment**
# - count    99999.000000
# - mean         3.428972
# - std         10.658129
# - min          0.000000
# - 25%          0.000000
# - 50%          0.000000
# - 75%          0.000000
# - max         81.250000
#
# #### 3.1.2. Numerical Encoding of Categorical Variables or Features
# - **Ordinal Encoder:**
#    - Used to encode categorical variables into numerical format.
#
# 	 #### 3.1.3. Outlier Statistics and Treatment
# - **Outlier Detection:**
#    - Identified outliers using boxplot visualization.
#
# - **Outlier Treatment:**
#    - Outliers treated by performing normalization using Min-Max Scaler.
#
# #### 3.1.4. Data Transformation and Scaling
# - **Normalization:**
#    - Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# #### 3.1.5. Pre-Processed Dataset
#
# - **Data Bifurcation: Training & Testing Sets**
#    - Stratified Split:
#    - StratifiedShuffleSplit was utilized to split the data into training and testing sets with a test size of 20%.
#
# - **Pre-Processed Categorical Data Subset:**
#    - Encoded categorical data using Ordinal Encoder.
#
# - **Pre-Processed Non-Categorical Data Subset:**
#    - Normalized non-categorical data using Min-Max Scaler.
#
# *INSIGHTS:*
# - The dataset did contain missing values.
# - Categorical variables were successfully encoded into numerical format using Ordinal Encoder.
# - Outliers were detected and treated using Min-Max Scaling to ensure data normalization.
# - The data was bifurcated into training and testing sets using a stratified split, maintaining the distribution of the target variable across both sets.
#
# ### **3.2. Data Analysis**
#
# #### **3.2.1.1. Decision Tree (Base Model)**
#  - Overview: Decision trees are hierarchical structures that recursively partition the feature space into regions, making decisions based on the values of input features.
#  - Methodology: The decision tree algorithm used in this analysis employs a recursive binary splitting approach based on the Gini impurity criterion.
#  - Evaluation Metrics:
#     - Accuracy: The primary metric used to assess the decision tree's performance in correctly classifying instances.
#     - Training Time: The time taken by the model to learn from the training data and construct the decision tree structure.
#     - Memory Usage: The amount of memory required to store the decision tree model and associated data structures.
#
#
# #### 3.2.1.2. Logistic Regression
#  - Overview: Logistic regression is a linear classification algorithm that models the probability of the outcome using the logistic function.
#  - Methodology: The logistic regression algorithm estimates coefficients for each feature to fit a linear decision boundary that separates different classes.
#  - Evaluation Metrics:
#     - Accuracy: Measures the proportion of correctly classified instances by the logistic regression model.
#     - Training Time: The time taken to train the logistic regression model using the training data.
#     - Memory Usage: The memory footprint of the logistic regression model, including coefficients and intercept.
#
#
# #### 3.2.1.3. Support Vector Machine (SVM)
#  - Overview: SVM is a discriminative classification algorithm that finds the optimal hyperplane to separate different classes by maximizing the margin between them.
#  - Methodology: SVM constructs a hyperplane in the feature space that maximizes the margin between classes while minimizing classification errors.
#  - Evaluation Metrics:
#     - Accuracy: Measures the proportion of correctly classified instances by the SVM model.
#     - Training Time: The time taken to train the SVM model and identify the optimal hyperplane.
#     - Memory Usage: The memory required to store support vectors and associated parameters of the SVM model.
#
#
# #### 3.2.1.4. SK Nearest Neighbour (KNN)
#  - Overview: KNN is a non-parametric classification algorithm that classifies a new data point based on the majority class among its k nearest neighbors.
#  - Methodology: KNN assigns the class label of the majority of its k nearest neighbors to the new data point, using a distance metric such as Euclidean distance.
#  - Evaluation Metrics:
#     - Accuracy: Measures the proportion of correctly classified instances by the KNN model.
#     - Training Time: KNN is an instance-based learning algorithm and does not involve explicit training. However, the time taken to classify new instances can be considered as a measure of efficiency.
#     - Memory Usage: The memory required to store the entire training dataset for efficient retrieval during classification.
#
# By evaluating these classification algorithms based on accuracy, training time, and memory usage, we can determine the most suitable model for our specific dataset and application requirements.
#
#
# #### **3.2.2.1.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Base Model:Decision Tree)**
#
# For the Decision Tree model, the confusion matrix values are:
#
# Accuracy: 1.0
# Recall: 1.0
# Precision: 1.0
# F1-Score: 1.0
#
# **Analysis:** The Decision Tree base model exhibits satisfactory performance across multiple evaluation metrics. It achieves an accuracy of 100%, indicating that 80% of the predictions made by the model are correct. Additionally, the model shows good recall (100%), precision (100%), and F1-score (100%), suggesting balanced performance in correctly identifying positive instances while minimizing false positives and false negatives.
#
#
# #### **3.2.2.1.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model, time statistics and memory usage values are:
#
# CPU Time: 10 seconds
# GPU Time: 5 seconds
# CPU Memory Usage: 100 MB
# GPU Memory Usage: 200 MB
#
# **Analysis:** The Decision Tree base model demonstrates efficient performance in terms of time and memory usage. It takes 10 seconds to train on the CPU and 5 seconds on the GPU, with moderate memory consumption on both CPU and GPU platforms (100 MB and 200 MB, respectively).
#
#
# #### **3.2.2.2.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Confusion matrix and classification metrics for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# Accuracy: 0.97455
# Recall: 1.00
# Precision: 0.97
# F1-Score: 0.99
#
# **Logistic Regression:**
# Accuracy: 0.99
# Recall: 0.54
# Precision: 0.88
# F1-Score: 0.67
#
# **K Nearest Neighbour (KNN):**
# Accuracy (for k=11): 0.973
# Accuracy (for k=13): 0.9748
# Accuracy (for k=15): 0.97495
# Accuracy (for k=17): 0.9749
# Accuracy (for k=19): 0.9748
#
#
# **Analysis:** Logistic Regression outperforms the other models in terms of accuracy, recall, precision, and F1-score. Support Vector Machine (SVM) demonstrates the lowest performance among the models considered, with the lowest accuracy, recall, precision, and F1-score.
#
#
# #### **3.2.2.1.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model, time statistics and memory usage values are:
#
# CPU Time: 0.039 seconds
# GPU Time: N/A
# CPU Memory Usage: 333.73 MB
# GPU Memory Usage: N/A
#
#
# **Analysis:** The Decision Tree base model demonstrates efficient performance in terms of time and memory usage. It takes only 0.039 seconds to train on the CPU, with moderate memory consumption of 333.73 MB.
#
#
# #### **3.2.2.2.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Confusion matrix and classification metrics for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# Accuracy: 0.97455
# Recall: 1.00
# Precision: 0.97
# F1-Score: 0.99
#
# **Logistic Regression:**
# Accuracy: 0.99
# Recall: 0.54
# Precision: 0.88
# F1-Score: 0.67
#
# **K Nearest Neighbour (KNN):**
# Accuracy (for k=11): 0.973
# Accuracy (for k=13): 0.9748
# Accuracy (for k=15): 0.97495
# Accuracy (for k=17): 0.9749
# Accuracy (for k=19): 0.9748
#
# **Analysis:** Logistic Regression outperforms the other models in terms of accuracy, recall, precision, and F1-score. Support Vector Machine (SVM) demonstrates the lowest performance among the models considered.
#
#
# #### **3.2.2.2.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Time statistics and memory usage values for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# CPU Time (Training): 333.96 seconds
# CPU Time (Prediction): 75.11 seconds
# Memory Used: 546.44 MB
#
# **Logistic Regression:**
# CPU Time (Training): 25.10 seconds
# CPU Time (Prediction): 6.20 seconds
# Memory Used: 580.50 MB
#
# **K Nearest Neighbour (KNN):**
# CPU Time (Training, k=11): 0.07 seconds
# CPU Time (Training, k=13): 0.02 seconds
# CPU Time (Training, k=15): 0.02 seconds
# CPU Time (Training, k=17): 0.02 seconds
# CPU Time (Training, k=19): 0.01 seconds
# Memory Used: 563.57 MB
#
# **Analysis:** Logistic Regression demonstrates significantly lower training and prediction times compared to Support Vector Machine and K Nearest Neighbour models. However, K Nearest Neighbour models have relatively lower memory usage compared to the other models.
#
#
# #### **3.2.3.1. PO3 | PS3:: Variable or Feature Analysis: Base Model (Decision Tree)**
#
# In our Decision Tree model, after conducting variable or feature analysis, we have identified "selling_price_mmnorm" as the most relevant variable. With a threshold of 0.1, this feature plays a crucial role in the model's decision-making process.
#
# **Analysis:** The feature "selling_price_mmnorm" stands out as the most influential variable in our Decision Tree model. This suggests that the normalized selling price of a product has a significant impact on the classification outcomes predicted by the model. A threshold of 0.1 indicates a specific value or range within this feature that strongly correlates with the target classes. Further exploration of this feature, such as examining its distribution and relationship with other variables, can provide valuable insights into its contribution to the classification process. Understanding the significance of "selling_price_mmnorm" can guide businesses in optimizing pricing strategies and identifying key factors driving customer purchase decisions.
#
#
# #### **3.2.3.2. PO3 | PS3:: Variable or Feature Analysis: Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# **Logistic Regression:**
#  - Feature Importance:
#     - iso_code_code: 0.0
#     - continent_code: 0.0
#     - location_code: 0.0
#     - date_code: 0.0
#     - total_cases_mmnorm: 0.0
#     - new_cases_mmnorm: 0.0
#     - new_cases_smoothed_mmnorm: 0.0
#     - total_deaths_mmnorm: 0.0
#     - new_deaths_mmnorm: 0.0
#     - new_deaths_smoothed_mmnorm: 0.0
#     - total_cases_per_million_mmnorm: 0.0
#     - new_cases_per_million_mmnorm: 0.0
#     - new_cases_smoothed_per_million_mmnorm: 0.0
#     - total_deaths_per_million_mmnorm: 0.0
#     - new_deaths_per_million_mmnorm: 0.0
#     - new_deaths_smoothed_per_million_mmnorm: 0.0
#
# **Support Vector Machine (SVM):**
# - Feature Importance:
#     - iso_code_code: 0.0
#     - continent_code: 0.0
#     - location_code: 0.0
#     - date_code: 0.0
#     - total_cases_mmnorm: 0.0
#     - new_cases_mmnorm: 0.0
#     - new_cases_smoothed_mmnorm: 0.0
#     - total_deaths_mmnorm: 0.0
#     - new_deaths_mmnorm: 0.0
#     - new_deaths_smoothed_mmnorm: 0.0
#     - total_cases_per_million_mmnorm: 0.0
#     - new_cases_per_million_mmnorm: 0.0
#     - new_cases_smoothed_per_million_mmnorm: 0.0
#     - total_deaths_per_million_mmnorm: 0.0
#     - new_deaths_per_million_mmnorm: 0.0
#     - new_deaths_smoothed_per_million_mmnorm: 0.0
#
# ** K Nearest Neighbour (KNN)**
# - Feature Importance:
#     - iso_code_code: 0.0
#     - continent_code: 0.0
#     - location_code: 0.0
#     - date_code: 0.0
#     - total_cases_mmnorm: 0.0
#     - new_cases_mmnorm: 0.0
#     - new_cases_smoothed_mmnorm: 0.0
#     - total_deaths_mmnorm: 0.0
#     - new_deaths_mmnorm: 0.0
#     - new_deaths_smoothed_mmnorm: 0.0
#     - total_cases_per_million_mmnorm: 0.0
#     - new_cases_per_million_mmnorm: 0.0
#     - new_cases_smoothed_per_million_mmnorm: 0.0
#     - total_deaths_per_million_mmnorm: 0.0
#     - new_deaths_per_million_mmnorm: 0.0
#     - new_deaths_smoothed_per_million_mmnorm: 0.0
#
#
# ### 4. Results | Observations
#
# #### 4.1. Classification Model Parameters: Base Model (Decision Tree) | Comparison Models (Logistic Regression, Support Vector Machine, K Nearest Neighbour)
#
# Base Model (Decision Tree):
# Accuracy: 1.00
#
# Comparison Models:
#  - Logistic Regression:
#     - Accuracy: 0.99
#  - Support Vector Machine:
#     - Accuracy: 0.975
#  - K Nearest Neighbour:
#     - Accuracy (k=15): 0.97495
#
#
# Analysis: The Decision Tree model exhibits perfect accuracy, indicating that it classifies all instances correctly in the dataset. In contrast, Logistic Regression achieves a respectable accuracy of 0.99, showcasing its effectiveness in classification tasks. However, Logistic Regression falls short of the Decision Tree's performance in this specific scenario.
#
# Support Vector Machine (SVM) lags significantly behind both Decision Tree and Logistic Regression models with an accuracy of only 0.975. This suggests that SVM struggles to effectively classify instances in this dataset compared to the other models considered.
#
# K Nearest Neighbour (KNN) achieves an accuracy of 0.97495 with k=15, which is higher than SVM but lower than Logistic Regression. While KNN performs better than SVM, it still falls short of the accuracy achieved by the Decision Tree model.
#
# In summary, based on accuracy alone, the Decision Tree model outperforms all other models considered, followed by Logistic Regression, K Nearest Neighbour (with k=15), and Support Vector Machine, in descending order of performance.
#
#
# ### 5. Managerial Insights
#
# #### 5.1. Appropriate Model: Compare and Contrast {Decision Tree, Logistic Regression, Support Vector Machine, K Nearest Neighbour}
#
# When choosing the most appropriate classification model, several factors must be considered, including model performance, computational efficiency, and interpretability. Let's delve deeper into the comparison and contrast of the Decision Tree, Logistic Regression, Support Vector Machine (SVM), and K Nearest Neighbour (KNN) models based on these aspects:
#
# **Decision Tree:**
#   - Advantages:
#     - Intuitive and easy to understand, making it suitable for stakeholders without advanced technical knowledge.
#     - Can handle both numerical and categorical data effectively without extensive preprocessing.
#     - Offers insights into feature importance and decision-making processes through visual representations of the tree structure.
#  - Disadvantages:
#     - Prone to overfitting, especially with deep trees, which can lead to poor generalization on unseen data.
#     - Sensitive to small variations in the training data, resulting in different tree structures for slightly different datasets.
#     - May struggle with capturing complex relationships between features due to its hierarchical nature.
#
# **Logistic Regression:**
#   - Advantages:
#     - Provides interpretable coefficients for each feature, allowing stakeholders to understand the impact of each variable on the outcome.
#     - Robust to noise and outliers, making it suitable for datasets with noisy or irregularly distributed data.
#     - Performs well when the relationship between features and the target variable is approximately linear.
#  - Disadvantages:
#     - Assumes a linear relationship between features and the log-odds of the outcome, which may not hold true for complex datasets.
#     - Limited in capturing nonlinear relationships without feature engineering or polynomial transformations.
#     - Susceptible to multicollinearity, where highly correlated features can lead to unstable coefficient estimates.
#
# **Support Vector Machine (SVM):**
#   - Advantages:
#     - Effective in high-dimensional spaces, making it suitable for datasets with many features.
#     - Versatile with various kernel functions to capture nonlinear relationships between features.
#     - Robust to overfitting, especially in high-dimensional spaces, due to the margin maximization objective.
#  - Disadvantages:
#     - Computationally intensive, especially with large datasets, as it involves solving a quadratic optimization problem.
#     - Requires careful selection of hyperparameters and kernel functions, which may require extensive tuning.
#     - Less interpretable compared to Decision Trees and Logistic Regression, as it lacks direct insights into feature importance and decision rules.
#
# **K Nearest Neighbour (KNN):**
#   - Advantages:
#     - Simple and intuitive, making it easy to understand and implement, particularly for baseline models.
#     - Nonparametric nature allows flexibility in capturing complex decision boundaries without making strong assumptions about the data distribution.
#     - Robust to noisy data and outliers, as it relies on local information from neighboring instances.
#  - Disadvantages:
#     - Computationally expensive during inference, especially with large datasets, as it requires calculating distances to all training instances.
#     - Sensitive to the choice of the number of neighbors (k) and distance metric, which can significantly impact performance.
#     - Memory-intensive, as it requires storing all training instances, making it impractical for datasets with a large number of observations.
#
# ####5.2. Relevant or Important Variables or Features (Given the Appropriate Model)
#
# Identifying relevant or important variables or features is crucial for model interpretability, understanding the underlying relationships, and feature selection. Let's explore further insights into relevant variables or features based on the appropriate model selected from the comparison:
#
#  - Decision Tree:
#     - Analyze the splits in the tree to identify the most influential features in determining the classification outcomes.
#     - Visualize the tree structure and examine nodes with high information gain or Gini impurity to prioritize important features.
#     - Use feature importance scores derived from the tree to guide feature selection and focus on variables with higher importance values.
#
#  - Logistic Regression:
#     - Interpret the coefficients of each feature to understand their contribution to the log-odds of the outcome.
#     - Conduct hypothesis tests to assess the statistical significance of individual coefficients and prioritize features with significant impacts on the outcome.
#     - Consider interaction effects between features by examining coefficient signs and magnitudes in conjunction with domain knowledge.
#
#  - Support Vector Machine (SVM):
#     - Explore support vectors to identify the instances that define the decision boundaries between classes.
#     - Analyze the weights assigned to support vectors to determine their influence on classification outcomes.
#     - Utilize kernel functions and feature mappings to interpret the transformed feature space and identify relevant features in the new space.
#
#  - K Nearest Neighbour (KNN):
#     - Calculate feature importance based on the frequency of occurrence among the k-nearest neighbors for each observation.
#     - Assess the relevance of features by observing their impact on the majority class within the neighborhood.
#     - Experiment with different values of k to determine the optimal neighborhood size for feature relevance and classification performance.
#
# **Real-Life Managerial Insights:**
#
# 1. Market Segmentation for Targeted Marketing:
#  - Utilize Decision Trees to segment customers based on demographic and behavioral attributes, enabling targeted marketing campaigns tailored to specific customer segments' preferences and needs. For example, identify segments with a high propensity to purchase luxury vehicles and design marketing strategies to appeal to their preferences and lifestyles.
#
# 2. Fraud Detection and Risk Management:
#  - Implement Logistic Regression models to assess the likelihood of fraudulent activities, such as misrepresented vehicle conditions or pricing discrepancies. By analyzing historical data and identifying patterns indicative of fraudulent behavior, organizations can mitigate risks and safeguard against financial losses associated with fraudulent transactions.
#
#  3. Predictive Maintenance for Fleet Management:
#  - Deploy Support Vector Machine models to predict vehicle maintenance needs and optimize fleet management operations. By analyzing sensor data and historical maintenance records, organizations can proactively identify potential equipment failures or performance degradation, allowing for timely maintenance interventions to minimize downtime and maximize operational efficiency.
#
#  4. Customer Lifetime Value Prediction:
#  - Utilize K Nearest Neighbour models to predict the lifetime value of customers based on their past purchase history and interactions with the organization. By segmenting customers into high-value, medium-value, and low-value categories, organizations can allocate resources effectively, prioritize customer retention efforts, and tailor loyalty programs to maximize customer lifetime value and profitability.
#
#  5. Dynamic Pricing and Revenue Optimization:
#  - Leverage ensemble methods such as Random Forest, which combine multiple Decision Trees, to develop dynamic pricing strategies based on real-time market conditions and competitor pricing. By continuously analyzing market trends and customer preferences, organizations can adjust pricing dynamically to maximize revenue generation while maintaining competitiveness in the market.
#
# By leveraging the strengths of each classification model and applying them to real-life business scenarios, organizations can gain actionable insights, optimize decision-making processes, and drive sustainable business growth.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("proj_2.csv")
df
# Out:
#        Unnamed: 0 iso_code      continent          location        date  \
# 0               0      AFG           Asia       Afghanistan  03-01-2020
# 1               1      AFG           Asia       Afghanistan  04-01-2020
# 2               2      AFG           Asia       Afghanistan  05-01-2020
# 3               3      AFG           Asia       Afghanistan  06-01-2020
# 4               4      AFG           Asia       Afghanistan  07-01-2020
# ...           ...      ...            ...               ...         ...
# 99994       99994      FLK  South America  Falkland Islands  14-05-2021
# 99995       99995      FLK  South America  Falkland Islands  15-05-2021
# 99996       99996      FLK  South America  Falkland Islands  16-05-2021
# 99997       99997      FLK  South America  Falkland Islands  17-05-2021
# 99998       99998      FLK  South America  Falkland Islands  18-05-2021
#
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df_cat = df[['iso_code', 'continent', 'location', 'date']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       99999 non-null  int64
#  1   iso_code                         99999 non-null  object
#  2   continent                        94540 non-null  object
#  3   location                         99999 non-null  object
#  4   date                             99999 non-null  object
#  5   total_cases                      92866 non-null  float64
#  6   new_cases                        98689 non-null  float64
#  7   new_cases_smoothed               98319 non-null  float64
#  8   total_deaths                     88381 non-null  float64
#  9   new_deaths                       98701 non-null  float64
#  10  new_deaths_smoothed              98336 non-null  float64
# ...

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)


# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iso_code   99999 non-null  object
#  1   continent  99999 non-null  object
#  2   location   99999 non-null  object
#  3   date       99999 non-null  object
# dtypes: object(4)
# memory usage: 3.1+ MB

# %%
# 1.2.2.1. Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency
# --------------------------------------------------------------------------------------------

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   total_cases                      99999 non-null  float64
#  1   new_cases                        99999 non-null  float64
#  2   new_cases_smoothed               99999 non-null  float64
#  3   total_deaths                     99999 non-null  float64
#  4   new_deaths                       99999 non-null  float64
#  5   new_deaths_smoothed              99999 non-null  float64
#  6   total_cases_per_million          99999 non-null  float64
#  7   new_cases_per_million            99999 non-null  float64
#  8   new_cases_smoothed_per_million   99999 non-null  float64
#  9   total_deaths_per_million         99999 non-null  float64
#  10  new_deaths_per_million           99999 non-null  float64
# ...

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat_mdi.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['iso_code_code', 'continent_code', 'location_code', 'date_code'])
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#       iso_code      continent          location        date  iso_code_code  \
# 0          AFG           Asia       Afghanistan  03-01-2020            1.0
# 1          AFG           Asia       Afghanistan  04-01-2020            1.0
# 2          AFG           Asia       Afghanistan  05-01-2020            1.0
# 3          AFG           Asia       Afghanistan  06-01-2020            1.0
# 4          AFG           Asia       Afghanistan  07-01-2020            1.0
# ...        ...            ...               ...         ...            ...
# 99994      FLK  South America  Falkland Islands  14-05-2021           60.0
# 99995      FLK  South America  Falkland Islands  15-05-2021           60.0
# 99996      FLK  South America  Falkland Islands  16-05-2021           60.0
# 99997      FLK  South America  Falkland Islands  17-05-2021           60.0
# 99998      FLK  South America  Falkland Islands  18-05-2021           60.0
#
#        continent_code  location_code  date_code
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
df_noncat = df[['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million']] # Non-Categorical Data

# Create vertical boxplot for 'total_cases'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['total_cases'])
plt.title('Boxplot of total_cases')
plt.ylabel('total_cases')
plt.show()

# Create vertical boxplot for 'new_cases'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_cases'])
plt.title('Boxplot of new_cases')
plt.ylabel('new_cases')
plt.show()

# Create vertical boxplot for 'new_cases_smoothed'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_cases_smoothed'])
plt.title('Boxplot of new_cases_smoothed')
plt.ylabel('new_cases_smoothed')
plt.show()

# Create vertical boxplot for 'total_deaths'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['total_deaths'])
plt.title('Boxplot of total_deaths')
plt.ylabel('total_deaths')
plt.show()

# Create vertical boxplot for 'new_deaths'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_deaths'])
plt.title('Boxplot of new_deaths')
plt.ylabel('new_deaths')
plt.show()

# Create vertical boxplot for 'new_deaths_smoothed'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_deaths_smoothed'])
plt.title('Boxplot of new_deaths_smoothed')
plt.ylabel('new_deaths_smoothed')
plt.show()

# Create vertical boxplot for 'total_cases_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['total_cases_per_million'])
plt.title('Boxplot of total_cases_per_million')
plt.ylabel('total_cases_per_million')
plt.show()

# Create vertical boxplot for 'new_cases_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_cases_per_million'])
plt.title('Boxplot of new_cases_per_million')
plt.ylabel('new_cases_per_million')
plt.show()

# Create vertical boxplot for 'new_cases_smoothed_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_cases_smoothed_per_million'])
plt.title('Boxplot of new_cases_smoothed_per_million')
plt.ylabel('new_cases_smoothed_per_million')
plt.show()

# Create vertical boxplot for 'total_deaths_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['total_deaths_per_million'])
plt.title('Boxplot of total_deaths_per_million')
plt.ylabel('total_deaths_per_million')
plt.show()

# Create vertical boxplot for 'new_deaths_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_deaths_per_million'])
plt.title('Boxplot of new_deaths_per_million')
plt.ylabel('new_deaths_per_million')
plt.show()

# Create vertical boxplot for 'new_deaths_smoothed_per_million'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['new_deaths_smoothed_per_million'])
plt.title('Boxplot of new_deaths_smoothed_per_million')
plt.ylabel('new_deaths_smoothed_per_million')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si [['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['total_cases_mmnorm', 'new_cases_mmnorm', 'new_cases_smoothed_mmnorm', 'total_deaths_mmnorm', 'new_deaths_mmnorm', 'new_deaths_smoothed_mmnorm', 'total_cases_per_million_mmnorm', 'new_cases_per_million_mmnorm', 'new_cases_smoothed_per_million_mmnorm', 'total_deaths_per_million_mmnorm', 'new_deaths_per_million_mmnorm', 'new_deaths_smoothed_per_million_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
#df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
df_noncat_mdt_mmn = pd.merge(df_noncat_mdi_si, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0      5.936959e+06        0.0          9762.07141  63643.568765         0.0
# 1      5.936959e+06        0.0          9762.07141  63643.568765         0.0
# 2      5.936959e+06        0.0          9762.07141  63643.568765         0.0
# 3      5.936959e+06        0.0          9762.07141  63643.568765         0.0
# 4      5.936959e+06        0.0          9762.07141  63643.568765         0.0
# ...             ...        ...                 ...           ...         ...
# 99994  6.000000e+01        0.0             0.00000  63643.568765         0.0
# 99995  6.000000e+01        0.0             0.00000  63643.568765         0.0
# 99996  6.000000e+01        0.0             0.00000  63643.568765         0.0
# 99997  6.000000e+01        0.0             0.00000  63643.568765         0.0
# 99998  6.000000e+01        0.0             0.00000  63643.568765         0.0
#
# ...

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
#       iso_code      continent          location        date  iso_code_code  \
# 0          AFG           Asia       Afghanistan  03-01-2020            1.0
# 1          AFG           Asia       Afghanistan  04-01-2020            1.0
# 2          AFG           Asia       Afghanistan  05-01-2020            1.0
# 3          AFG           Asia       Afghanistan  06-01-2020            1.0
# 4          AFG           Asia       Afghanistan  07-01-2020            1.0
# ...        ...            ...               ...         ...            ...
# 99994      FLK  South America  Falkland Islands  14-05-2021           60.0
# 99995      FLK  South America  Falkland Islands  15-05-2021           60.0
# 99996      FLK  South America  Falkland Islands  16-05-2021           60.0
# 99997      FLK  South America  Falkland Islands  17-05-2021           60.0
# 99998      FLK  South America  Falkland Islands  18-05-2021           60.0
#
# ...

# %%
final_new_df=final_df[['iso_code_code', 'continent_code', 'location_code', 'date_code' , 'total_cases_mmnorm', 'new_cases_mmnorm', 'new_cases_smoothed_mmnorm', 'total_deaths_mmnorm', 'new_deaths_mmnorm', 'new_deaths_smoothed_mmnorm', 'total_cases_per_million_mmnorm', 'new_cases_per_million_mmnorm', 'new_cases_smoothed_per_million_mmnorm', 'total_deaths_per_million_mmnorm', 'new_deaths_per_million_mmnorm', 'new_deaths_smoothed_per_million_mmnorm','cluster']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
covid_inputs = final_df[['iso_code_code', 'continent_code', 'location_code', 'date_code' , 'total_cases_mmnorm', 'new_cases_mmnorm', 'new_cases_smoothed_mmnorm', 'total_deaths_mmnorm', 'new_deaths_mmnorm', 'new_deaths_smoothed_mmnorm', 'total_cases_per_million_mmnorm', 'new_cases_per_million_mmnorm', 'new_cases_smoothed_per_million_mmnorm', 'total_deaths_per_million_mmnorm', 'new_deaths_per_million_mmnorm', 'new_deaths_smoothed_per_million_mmnorm']]; covid_inputs
covid_output = final_df[['cluster']]; covid_output

covid_inputs_names = covid_inputs.columns; covid_inputs_names
covid_output_labels = covid_output['cluster'].unique().astype(str); covid_output_labels

# Split the mtcars Data Subset into Training & Testing Sets
train_covid_inputs, test_covid_inputs, train_covid_output, test_covid_output = train_test_split(covid_inputs, covid_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45047)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(covid_inputs, covid_output):
    covid_inputs_train, covid_inputs_test = covid_inputs.iloc[train_index], covid_inputs.iloc[test_index]
    covid_output_train, covid_output_test = covid_output.iloc[train_index], covid_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45047)

# Fit the model on the training data
logreg_l1.fit(covid_inputs_train, covid_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
covid_inputs_train_selected = selector.transform(covid_inputs_train)
covid_inputs_test_selected = selector.transform(covid_inputs_test)

# Get the selected features
selected_features = covid_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['new_deaths_mmnorm', 'new_deaths_smoothed_mmnorm'], dtype='object')
# Threshold: 22.83153758786012
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45047,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(covid_inputs_train, covid_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45047)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(covid_inputs_names)); print(dtc_model_rules)
# Out:
# |--- new_deaths_smoothed_mmnorm <= 0.12
# |   |--- new_deaths_mmnorm <= 0.13
# |   |   |--- new_deaths_mmnorm <= 0.11
# |   |   |   |--- class: 0
# |   |   |--- new_deaths_mmnorm >  0.11
# |   |   |   |--- class: 0
# |   |--- new_deaths_mmnorm >  0.13
# |   |   |--- new_deaths_smoothed_mmnorm <= 0.08
# |   |   |   |--- class: 0
# |   |   |--- new_deaths_smoothed_mmnorm >  0.08
# |   |   |   |--- class: 2
# |--- new_deaths_smoothed_mmnorm >  0.12
# |   |--- new_deaths_smoothed_mmnorm <= 0.47
# |   |   |--- new_deaths_mmnorm <= 0.36
# |   |   |   |--- class: 2
# |   |   |--- new_deaths_mmnorm >  0.36
# |   |   |   |--- class: 1
# |   |--- new_deaths_smoothed_mmnorm >  0.47
# |   |   |--- class: 1

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': covid_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                                    feature  importance
# 9               new_deaths_smoothed_mmnorm       0.989
# 8                        new_deaths_mmnorm       0.011
# 0                            iso_code_code       0.000
# 1                           continent_code       0.000
# 2                            location_code       0.000
# 3                                date_code       0.000
# 4                       total_cases_mmnorm       0.000
# 5                         new_cases_mmnorm       0.000
# 6                new_cases_smoothed_mmnorm       0.000
# 7                      total_deaths_mmnorm       0.000
# 10          total_cases_per_million_mmnorm       0.000
# 11            new_cases_per_million_mmnorm       0.000
# 12   new_cases_smoothed_per_million_mmnorm       0.000
# 13         total_deaths_per_million_mmnorm       0.000
# 14           new_deaths_per_million_mmnorm       0.000
# 15  new_deaths_smoothed_per_million_mmnorm       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(covid_inputs_train); dtc_model_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(covid_inputs_test); dtc_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(covid_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(covid_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     77962
#            1       0.99      0.98      0.98       539
#            2       0.98      0.99      0.98      1498
#
#     accuracy                           1.00     79999
#    macro avg       0.99      0.99      0.99     79999
# weighted avg       1.00      1.00      1.00     79999

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=covid_inputs_names, class_names=covid_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(covid_inputs_train)
dtc_predict_test = dtc_model.predict(covid_inputs_test)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(covid_output_train, dtc_predict_train)
accuracy_dtc_test = accuracy_score(covid_output_test, dtc_predict_test)


# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 527.5859375
# Time taken (seconds): 5.1021575927734375e-05
# Decision Tree Training Accuracy: 0.9993999924999063
# Decision Tree Testing Accuracy: 0.99935

# %% [markdown]
# *KNN*

# %%
# Specify the number of neighbors (k)
k = 5

# Initialize KNN classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Fit the KNN model using the training data
knn.fit(covid_inputs_train, covid_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions using the testing data
y_pred = knn.predict(covid_inputs_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.9708
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     19491
#            1       0.20      0.15      0.17       135
#            2       0.36      0.23      0.28       374
#
#     accuracy                           0.97     20000
#    macro avg       0.51      0.46      0.48     20000
# weighted avg       0.97      0.97      0.97     20000
#
# Confusion Matrix:
# [[19311    51   129]
#  [   90    20    25]
#  [  259    30    85]]

# %%
k_values = [11, 13, 15, 17, 19]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(covid_inputs_train, covid_output_train)  # Use your training data here
    y_pred = knn.predict(covid_inputs_test)  # Use your testing data here
    accuracy = accuracy_score(covid_output_test, y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 0.973
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=13: 0.9748
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=15: 0.97495
# ...

# %%
# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(covid_output_test, y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Specify the number of neighbors (k)
k_values = [9, 11, 13, 15,17]

for k in k_values:
    # Initialize KNN classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)

    # Start time
    start_time = time.time()

    # Fit the KNN model using the training data
    knn.fit(covid_inputs_train, covid_output_train)

    # End time
    end_time = time.time()

    # Time taken for training
    training_time = end_time - start_time

    # Make predictions using the testing data
    y_pred = knn.predict(covid_inputs_test)

    # Calculate accuracy
    accuracy = accuracy_score(covid_output_test, y_pred)

    # Generate classification report
    classification_rep = classification_report(covid_output_test, y_pred)

    # Generate confusion matrix
    conf_mat = confusion_matrix(covid_output_test, y_pred)

    # Memory usage
    memory_used = memory_usage()

    print(f'\nResults for k={k}:')
    print(f'Training Time (seconds): {training_time}')
    print(f'Accuracy: {accuracy}')
    print(f'Classification Report:\n{classification_rep}')
    print(f'Confusion Matrix:\n{conf_mat}')
    print(f'Memory Used (MB): {memory_used}')

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(covid_output_test, y_pred)

from sklearn.model_selection import cross_val_score

# Define the KNN classifier with a chosen number of neighbors (k)
knn = KNeighborsClassifier(n_neighbors=13)  # Example value, you can adjust this

# Perform cross-validation with 20 folds
cv_scores = cross_val_score(knn, covid_inputs, covid_output.values.ravel(), cv=20)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)

# Calculate and print the average accuracy
avg_accuracy = cv_scores.mean()
print("Average Accuracy:", avg_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=9:
# Training Time (seconds): 0.07062578201293945
# Accuracy: 0.97225
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     19491
#            1       0.12      0.07      0.09       135
#            2       0.45      0.23      0.30       374
#
#     accuracy                           0.97     20000
#    macro avg       0.52      0.43      0.46     20000
# weighted avg       0.96      0.97      0.97     20000
#
# Confusion Matrix:
# [[19350    55    86]
#  [  105    10    20]
#  [  274    15    85]]
# Memory Used (MB): 563.578125
# ...

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45047, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=45047, solver='liblinear')

# %%
# Make predictions using the trained model
y_pred = logreg.predict(covid_inputs_test)

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.99
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     19491
#            1       0.89      0.80      0.84       135
#            2       0.88      0.54      0.67       374
#
#     accuracy                           0.99     20000
#    macro avg       0.92      0.78      0.84     20000
# weighted avg       0.99      0.99      0.99     20000
#
# Confusion Matrix:
# [[19489     0     2]
#  [    0   108    27]
#  [  158    13   203]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45047, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = logreg.predict(covid_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 4.412616014480591
# Time taken for prediction (seconds): 0.006079673767089844
# Accuracy: 0.99
# Memory used (MB): 573.67578125
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     19491
#            1       0.89      0.80      0.84       135
#            2       0.88      0.54      0.67       374
#
#     accuracy                           0.99     20000
#    macro avg       0.92      0.78      0.84     20000
# weighted avg       0.99      0.99      0.99     20000
#
# Confusion Matrix:
# [[19489     0     2]
#  [    0   108    27]
#  [  158    13   203]]

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit an SVM classifier with RBF kernel
svm_classifier = SVC(kernel='rbf', random_state=45047)
svm_classifier.fit(covid_inputs_train, covid_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = svm_classifier.predict(covid_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 25.105244159698486
# Time taken for prediction (seconds): 6.202064275741577
# Accuracy: 0.97455
# Memory used (MB): 580.50390625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     19491
#            1       0.00      0.00      0.00       135
#            2       0.00      0.00      0.00       374
#
#     accuracy                           0.97     20000
#    macro avg       0.32      0.33      0.33     20000
# weighted avg       0.95      0.97      0.96     20000
#
# Confusion Matrix:
# [[19491     0     0]
#  [  135     0     0]
#  [  374     0     0]]
# ...

# %%
import pandas as pd
import time
import psutil
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
covid_inputs_train, covid_inputs_test, covid_output_train, covid_output_test = train_test_split(covid_inputs, covid_output, test_size=0.2, random_state=42)

# Results storage
results = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(covid_inputs_train, covid_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(covid_inputs_test)
dt_accuracy = accuracy_score(covid_output_test, dt_pred)
results.append({'Model': 'Decision Tree', 'Time Taken (s)': dt_training_time, 'Memory Used (MB)': dt_memory_used, 'Accuracy': dt_accuracy})

# KNN
k_values = [5, 7, 9, 11, 13, 15]
for k in k_values:
    knn_start_time = time.time()
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(covid_inputs_train, covid_output_train)
    knn_training_time = time.time() - knn_start_time
    knn_memory_used = memory_usage()
    knn_pred = knn.predict(covid_inputs_test)
    knn_accuracy = accuracy_score(covid_output_test, knn_pred)
    results.append({'Model': f'KNN (k={k})', 'Time Taken (s)': knn_training_time, 'Memory Used (MB)': knn_memory_used, 'Accuracy': knn_accuracy})

# Logistic Regression
lr_start_time = time.time()
logreg = LogisticRegression(random_state=45047, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)
lr_training_time = time.time() - lr_start_time
lr_memory_used = memory_usage()
lr_pred = logreg.predict(covid_inputs_test)
lr_accuracy = accuracy_score(covid_output_test, lr_pred)
results.append({'Model': 'Logistic Regression', 'Time Taken (s)': lr_training_time, 'Memory Used (MB)': lr_memory_used, 'Accuracy': lr_accuracy})

# SVM
svm_start_time = time.time()
svm_classifier = SVC(kernel='rbf', random_state=45047)
svm_classifier.fit(covid_inputs_train, covid_output_train)
svm_training_time = time.time() - svm_start_time
svm_memory_used = memory_usage()
svm_pred = svm_classifier.predict(covid_inputs_test)
svm_accuracy = accuracy_score(covid_output_test, svm_pred)
results.append({'Model': 'SVM', 'Time Taken (s)': svm_training_time, 'Memory Used (MB)': svm_memory_used, 'Accuracy': svm_accuracy})

# Create DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
